# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/Projects/Brox_Optical_Flow"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3

# %%
# Download Dataset
# !pip install kaggle
# !mkdir -p ~/.kaggle

from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d artemmmtry/mpi-sintel-dataset
# !unzip mpi-sintel-dataset.zip -d MPI_Sintel

# %%
# Estimate Brox

# !python /content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu/main.py \
   --task "estimate"\
   --input_dir "/content/drive/MyDrive/Projects/Datasets/Middlebury/Input" \
   --gt_dir "" \
   --solver "CG"
# Out:
# Number of sequences: 8
# The sequence dimetrodon has 2 frames in the shape of (388, 584).
# The sequence grove2 has 2 frames in the shape of (480, 640).
# The sequence grove3 has 2 frames in the shape of (480, 640).
# The sequence hydrangea has 2 frames in the shape of (388, 584).
# The sequence rubberwhale has 2 frames in the shape of (388, 584).
# The sequence urban2 has 2 frames in the shape of (480, 640).
# The sequence urban3 has 2 frames in the shape of (480, 640).
# The sequence venus has 2 frames in the shape of (380, 420).

# %%
# Estimate RAFT
# !python /content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3/raft_estimator.py \
    --img1_path  "/content/drive/MyDrive/Projects/Datasets/Middlebury/Input/dimetrodon_frame10.png" \
    --img2_path  "/content/drive/MyDrive/Projects/Datasets/Middlebury/Input/dimetrodon_frame11.png" \
    --output_dir "/content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3/results/raft_flows"
# Out:
# Downloading: "https://download.pytorch.org/models/raft_large_C_T_SKHT_V2-ff5fadd5.pth" to /root/.cache/torch/hub/checkpoints/raft_large_C_T_SKHT_V2-ff5fadd5.pth
# 100% 20.1M/20.1M [00:00<00:00, 89.2MB/s]
# Flow computation and visualization completed successfully

# %%
# Evaluate

# !python /content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3/main.py \
   --task "evaluate" \
   --input_dir "/content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3/results/est_flows" \
   --gt_dir "/content/drive/MyDrive/Projects/Datasets/Middlebury/gt"
# Out:
# Number of sequences: 1
# d0_10: 215820, d10_40: 0, d40_inf: 0, valid: 95.25%
# /content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3/utils.py:224: RuntimeWarning: Mean of empty slice.
#   d10_40_epe = epe[d10_40_mask & valid_gt].mean()
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /content/drive/MyDrive/Projects/Brox_Optical_Flow_cpu_3/utils.py:225: RuntimeWarning: Mean of empty slice.
#   d40_inf_epe = epe[d40_inf_mask & valid_gt].mean()
# d0_10_epe: 0.18599076569080353, d10_40_epe: nan, d40_inf_epe: nan
# EPE for sequence dimetrodon: 0.18599076569080353
#
#
# EPE_all: 0.18599076569080353
# F1_all: 0.7047585951255676
